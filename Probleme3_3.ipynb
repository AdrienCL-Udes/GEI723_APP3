# %% [markdown]
# ## Problème 3: Fonction de ReLu $\alpha = -1$

# %% [markdown]
# #### Packages et imports

# %%
# pip install torch quantities sparse==0.11.0 > /dev/null

import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, model_selection, utils
import torch
import quantities as units
from sparse import COO

# %% [markdown]
# #### Configuration

# %%
# Reproducibility
torch.manual_seed(0)
np.random.seed(0)

# Use the GPU unless there is none available.
# If you don't have a CUDA enabled GPU, I recommned using Google Colab,
# available at https://colab.research.google.com. Create a new notebook
# and then go to Runtime -> Change runtime type -> Hardware accelerator -> GPU
# Colab gives you access to up to 12 free continuous hours of a fairly recent GPU.
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# #### Préparation des données

# %%
# Let's download the MNIST dataset, available at https://www.openml.org/d/554
# You can edit the argument data_home to the directory of your choice.
# The dataset will be downloaded there; the default directory is ~/scikit_learn_data/
X, y = datasets.fetch_openml('mnist_784', version=1, return_X_y=True, data_home=None, as_frame=False)
nb_of_samples, nb_of_features = X.shape
# X = 70k samples, 28*28 features; y = 70k samples, 1 label (string)

# Shuffle the dataset
X, y = utils.shuffle(X, y)

# Convert the labels (string) to integers for convenience
y = np.array(y, dtype=int)
nb_of_ouputs = np.max(y) + 1

# We'll normalize our input data in the range [0, 1[.
X = X / pow(2, 8)
# Out:
# C:\Users\AdrienLaptop\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\datasets\_openml.py:1022: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %% [markdown]
# #### Conversion en décharges

# %%
# And convert the data to a spike train using TTFS encoding
dt = 1*units.ms
duration_per_image = 100*units.ms
absolute_duration = int(duration_per_image / dt)

time_of_spike = (1 - X) * absolute_duration  # The brighter the pixel, the earlier the spike
time_of_spike[X < .25] = 0  # "Remove" the spikes associated with darker pixels, which presumably carry less information

sample_id, neuron_idx = np.nonzero(time_of_spike)

# We use a sparse COO array to store the spikes for memory requirements
# You can use the spike_train variable as if it were a tensor of shape (nb_of_samples, nb_of_features, absolute_duration)
spike_train = COO((sample_id, neuron_idx, time_of_spike[sample_id, neuron_idx]),
                  np.ones_like(sample_id), shape=(nb_of_samples, nb_of_features, absolute_duration))

# %% [markdown]
# #### Split entrainement/test

# %%
# Split in train/test
nb_of_train_samples = int(nb_of_samples * 0.85)  # Keep 15% of the dataset for testing
train_indices = np.arange(nb_of_train_samples)
test_indices = np.arange(nb_of_train_samples, nb_of_samples)

# %% [markdown]
# #### Création du réseau

# %%
# We create a 2 layer network (1 hidden, 1 output)
nb_hidden = 128  # Number of hidden neurons

w1 = torch.empty((nb_of_features, nb_hidden), device=device, dtype=torch.float, requires_grad=True)
torch.nn.init.normal_(w1, mean=0., std=.1)

w2 = torch.empty((nb_hidden, nb_of_ouputs), device=device, dtype=torch.float, requires_grad=True)
torch.nn.init.normal_(w2, mean=0., std=.1)
# Out:
# tensor([[ 0.0166, -0.0201, -0.0915,  ...,  0.1204, -0.0279,  0.1034],
#         [ 0.0904, -0.0630, -0.0854,  ...,  0.1121, -0.0862, -0.1139],
#         [ 0.0663, -0.0444,  0.0240,  ...,  0.0991, -0.0835,  0.0579],
#         ...,
#         [-0.2037,  0.0690,  0.0162,  ..., -0.0634,  0.0101, -0.0868],
#         [ 0.0544, -0.1185,  0.1433,  ..., -0.0279, -0.0658,  0.1325],
#         [ 0.0045,  0.0288,  0.0155,  ..., -0.0239, -0.0366, -0.0218]],
#        requires_grad=True)

# %%
"""
Cette class permet de calculer la sortie d'une fonction lors de la propagation avant et de personaliser la derivée lors de la retropropagation de l'erreur.
Voir cet exemple pour plus de détails : https://pytorch.org/tutorials/beginner/examples_autograd/two_layer_net_custom_function.html
"""
class SpikeFunction(torch.autograd.Function):
    """
    Dans la passe avant, nous recevons un tenseur contenant l'entrée (potential-threshold).
    Nous appliquons la fonction Heaviside et renvoyons un tenseur contenant la sortie.
    """
    @staticmethod
    def forward(ctx, input):
        ctx.save_for_backward(input)
        out = torch.zeros_like(input)
        out[input > 0] = 1.0 # On génère une décharge quand (potential-threshold) > 0
        return out

    """
    Dans la passe arrière, nous recevons un tenseur contenant le gradient de l'erreur par rapport à la sortie.
    Nous calculons le gradient de l'erreur par rapport à l'entrée en utilisant la dérivée de la fonction ReLu.
    """
    @staticmethod
    def backward(ctx, grad_output):
        input, = ctx.saved_tensors
        grad_relu = torch.ones_like(input) # The derivativen ReLU function
        grad_relu[input < 0] = -1          # Apply alpha = -1 to negative input
        return grad_output.clone()*grad_relu

# %%
def run_spiking_layer(input_spike_train, layer_weights, tau_v=20*units.ms, tau_i=5*units.ms, v_threshold=1.0):
    """Here we implement a current-LIF dynamic in PyTorch"""

    # First, we multiply the input spike train by the weights of the current layer to get the current that will be added
    # We can calculate this beforehand because the weights are constant in the forward pass (no plasticity)
    input_current = torch.einsum("abc,bd->adc", (input_spike_train, layer_weights))  # Equivalent to a matrix multiplication for tensors of dim > 2 using Einstein's Notation

    recorded_spikes = []  # Array of the output spikes at each time t
    membrane_potential_at_t = torch.zeros((input_spike_train.shape[0], layer_weights.shape[-1]), device=device, dtype=torch.float)
    membrane_current_at_t = torch.zeros((input_spike_train.shape[0], layer_weights.shape[-1]), device=device, dtype=torch.float)

    const_a = 1*units.ms / tau_i
    alpha = np.exp(-(const_a.item()))

    const_b = 1*units.ms / tau_v
    beta = np.exp(-(const_b.item()))

    for t in range(absolute_duration):  # For every timestep
        # Apply the leak
        membrane_potential_at_t = torch.mul(membrane_potential_at_t, beta) # Using tau_v with euler or exact method
        membrane_current_at_t = torch.mul(membrane_current_at_t, alpha) # Using tau_i with euler or exact method

        # Select the input current at time t
        input_at_t = input_current[:, :, t]

        # Integrate the input current
        membrane_current_at_t += input_at_t

        # Integrate the input to the membrane potential
        membrane_potential_at_t += membrane_current_at_t

        # Apply the non-differentiable function
        recorded_spikes_at_t = SpikeFunction.apply(membrane_potential_at_t - v_threshold)
        recorded_spikes.append(recorded_spikes_at_t)

        # Reset the spiked neurons
        membrane_potential_at_t[membrane_potential_at_t > v_threshold] = 0

    recorded_spikes = torch.stack(recorded_spikes, dim=2) # Stack over time axis (Array -> Tensor)
    return recorded_spikes

# %% [markdown]
# #### Entrainement

# %%
# Set-up training
nb_of_epochs = 4
batch_size = 256  # The backpropagation is done after every batch, but a batch here is also used for memory requirements
number_of_batches = len(train_indices) // batch_size

params = [w1, w2]  # Trainable parameters
optimizer = torch.optim.Adam(params, lr=0.01, amsgrad=True)
loss_fn = torch.nn.MSELoss(reduction='mean')

for e in range(nb_of_epochs):
    epoch_loss = 0
    i = 0
    for batch in np.array_split(train_indices, number_of_batches):
        i += 1
        # Select batch and convert to tensors
        batch_spike_train = torch.FloatTensor(spike_train[batch].todense()).to(device)
        batch_labels = torch.LongTensor(y[batch, np.newaxis]).to(device)

        # Here we create a target spike count (10 spikes for wrong label, 100 spikes for true label) in a one-hot fashion
        # This approach is seen in Shrestha & Orchard (2018) https://arxiv.org/pdf/1810.08646.pdf
        # Code available at https://github.com/bamsumit/slayerPytorch
        min_spike_count = 10 * torch.ones((batch.shape[0], 10), device=device, dtype=torch.float)
        target_output = min_spike_count.scatter_(1, batch_labels, 100.0)

        # Forward propagation
        layer_1_spikes = run_spiking_layer(batch_spike_train, w1)
        layer_2_spikes = run_spiking_layer(layer_1_spikes, w2)
        network_output = torch.sum(layer_2_spikes, 2)  # Count the spikes over time axis
        loss = loss_fn(network_output, target_output)

        # Backward propagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()

        print("Batch %i out of %i in Epoch %i -- loss : %.4f" %(i, number_of_batches, e+1, loss.item()))
    
    print("Epoch %i -- loss : %.4f" %(e+1, epoch_loss / number_of_batches))
# Out:
# Batch 1 out of 232 in Epoch 1 -- loss : 966.2136
# Batch 2 out of 232 in Epoch 1 -- loss : 910.7736
# Batch 3 out of 232 in Epoch 1 -- loss : 890.5677
# Batch 4 out of 232 in Epoch 1 -- loss : 876.4860
# Batch 5 out of 232 in Epoch 1 -- loss : 956.6502
# Batch 6 out of 232 in Epoch 1 -- loss : 1008.2187
# Batch 7 out of 232 in Epoch 1 -- loss : 1042.6039
# Batch 8 out of 232 in Epoch 1 -- loss : 1101.0673
# Batch 9 out of 232 in Epoch 1 -- loss : 1109.9965
# Batch 10 out of 232 in Epoch 1 -- loss : 1074.6003
# Batch 11 out of 232 in Epoch 1 -- loss : 1080.3397
# Batch 12 out of 232 in Epoch 1 -- loss : 1044.1533
# Batch 13 out of 232 in Epoch 1 -- loss : 1082.0094
# Batch 14 out of 232 in Epoch 1 -- loss : 1028.6183
# Batch 15 out of 232 in Epoch 1 -- loss : 1038.1078
# Batch 16 out of 232 in Epoch 1 -- loss : 1054.1190
# Batch 17 out of 232 in Epoch 1 -- loss : 1043.8545
# Batch 18 out of 232 in Epoch 1 -- loss : 1049.0898
# Batch 19 out of 232 in Epoch 1 -- loss : 1089.8168
# Batch 20 out of 232 in Epoch 1 -- loss : 1085.2191
# Batch 21 out of 232 in Epoch 1 -- loss : 1068.3685
# Batch 22 out of 232 in Epoch 1 -- loss : 1061.8696
# Batch 23 out of 232 in Epoch 1 -- loss : 1054.4642
# Batch 24 out of 232 in Epoch 1 -- loss : 1069.2483
# Batch 25 out of 232 in Epoch 1 -- loss : 1105.1775
# Batch 26 out of 232 in Epoch 1 -- loss : 1040.8572
# Batch 27 out of 232 in Epoch 1 -- loss : 1054.1467
# Batch 28 out of 232 in Epoch 1 -- loss : 1051.6405
# Batch 29 out of 232 in Epoch 1 -- loss : 1094.6693
# Batch 30 out of 232 in Epoch 1 -- loss : 1068.3086
# Batch 31 out of 232 in Epoch 1 -- loss : 1037.8490
# Batch 32 out of 232 in Epoch 1 -- loss : 1088.7245
# Batch 33 out of 232 in Epoch 1 -- loss : 1078.9790
# Batch 34 out of 232 in Epoch 1 -- loss : 1058.2097
# Batch 35 out of 232 in Epoch 1 -- loss : 1068.9642
# Batch 36 out of 232 in Epoch 1 -- loss : 1058.4724
# Batch 1 out of 232 in Epoch 3 -- loss : 1075.5020
# Batch 2 out of 232 in Epoch 3 -- loss : 1053.1490
# Batch 3 out of 232 in Epoch 3 -- loss : 1053.8315
# Batch 4 out of 232 in Epoch 3 -- loss : 1058.7572
# Batch 5 out of 232 in Epoch 3 -- loss : 1064.7972
# Batch 6 out of 232 in Epoch 3 -- loss : 1052.0610
# Batch 7 out of 232 in Epoch 3 -- loss : 1131.2460
# Batch 8 out of 232 in Epoch 3 -- loss : 1056.0770
# Batch 9 out of 232 in Epoch 3 -- loss : 1048.8568
# Batch 10 out of 232 in Epoch 3 -- loss : 1031.4669
# Batch 11 out of 232 in Epoch 3 -- loss : 1048.8712
# Batch 12 out of 232 in Epoch 3 -- loss : 1024.0996
# Batch 13 out of 232 in Epoch 3 -- loss : 1076.7665
# Batch 14 out of 232 in Epoch 3 -- loss : 1114.9696
# Batch 15 out of 232 in Epoch 3 -- loss : 1042.5505
# Batch 16 out of 232 in Epoch 3 -- loss : 1050.6619
# Batch 17 out of 232 in Epoch 3 -- loss : 1036.3751
# Batch 18 out of 232 in Epoch 3 -- loss : 1031.3572
# Batch 19 out of 232 in Epoch 3 -- loss : 1065.4420
# Batch 20 out of 232 in Epoch 3 -- loss : 1058.8303
# Batch 21 out of 232 in Epoch 3 -- loss : 1135.8595
# Batch 22 out of 232 in Epoch 3 -- loss : 1051.5623
# Batch 23 out of 232 in Epoch 3 -- loss : 1042.8066
# Batch 24 out of 232 in Epoch 3 -- loss : 1055.5630
# Batch 25 out of 232 in Epoch 3 -- loss : 1076.4895
# Batch 26 out of 232 in Epoch 3 -- loss : 1029.7296
# Batch 27 out of 232 in Epoch 3 -- loss : 1037.6541
# Batch 28 out of 232 in Epoch 3 -- loss : 1065.0879
# Batch 29 out of 232 in Epoch 3 -- loss : 1112.1012
# Batch 30 out of 232 in Epoch 3 -- loss : 1042.8981
# Batch 31 out of 232 in Epoch 3 -- loss : 1010.9284
# Batch 32 out of 232 in Epoch 3 -- loss : 1054.5035
# Batch 33 out of 232 in Epoch 3 -- loss : 1057.6101
# Batch 34 out of 232 in Epoch 3 -- loss : 1086.0420
# Batch 35 out of 232 in Epoch 3 -- loss : 1053.2198
# Batch 36 out of 232 in Epoch 3 -- loss : 1046.6910
# Batch 37 out of 232 in Epoch 3 -- loss : 1076.1444
# Batch 38 out of 232 in Epoch 3 -- loss : 1019.9183
# Batch 39 out of 232 in Epoch 3 -- loss : 1062.1930
# Batch 40 out of 232 in Epoch 3 -- loss : 1051.6775
# Batch 41 out of 232 in Epoch 3 -- loss : 1100.9109
# Batch 42 out of 232 in Epoch 3 -- loss : 1056.3483
# Batch 43 out of 232 in Epoch 3 -- loss : 1098.6965
# Batch 44 out of 232 in Epoch 3 -- loss : 1033.1046
# Batch 45 out of 232 in Epoch 3 -- loss : 1035.2054
# Batch 46 out of 232 in Epoch 3 -- loss : 1032.3817
# Batch 47 out of 232 in Epoch 3 -- loss : 1021.8506
# Batch 48 out of 232 in Epoch 3 -- loss : 1092.5199
# Batch 49 out of 232 in Epoch 3 -- loss : 1072.6875
# Batch 50 out of 232 in Epoch 3 -- loss : 1037.3680
# Batch 51 out of 232 in Epoch 3 -- loss : 1048.3011
# Batch 52 out of 232 in Epoch 3 -- loss : 1087.2024
# Batch 53 out of 232 in Epoch 3 -- loss : 1051.2798
# Batch 54 out of 232 in Epoch 3 -- loss : 1032.4479
# Batch 55 out of 232 in Epoch 3 -- loss : 1082.2942
# Batch 56 out of 232 in Epoch 3 -- loss : 1078.2444
# Batch 57 out of 232 in Epoch 3 -- loss : 1012.2039
# Batch 58 out of 232 in Epoch 3 -- loss : 1036.4895
# Batch 59 out of 232 in Epoch 3 -- loss : 1100.1514
# Batch 60 out of 232 in Epoch 3 -- loss : 1053.6526
# Batch 61 out of 232 in Epoch 3 -- loss : 1020.5552
# Batch 62 out of 232 in Epoch 3 -- loss : 1121.9167
# Batch 63 out of 232 in Epoch 3 -- loss : 1065.7693
# Batch 64 out of 232 in Epoch 3 -- loss : 1062.8623
# Batch 65 out of 232 in Epoch 3 -- loss : 1086.6510
# Batch 66 out of 232 in Epoch 3 -- loss : 1047.0809
# Batch 67 out of 232 in Epoch 3 -- loss : 1116.2471
# Batch 68 out of 232 in Epoch 3 -- loss : 1066.7389
# Batch 69 out of 232 in Epoch 3 -- loss : 1056.2490
# Batch 70 out of 232 in Epoch 3 -- loss : 1095.6996
# Batch 71 out of 232 in Epoch 3 -- loss : 1058.0941
# Batch 72 out of 232 in Epoch 3 -- loss : 1061.3643
# Batch 73 out of 232 in Epoch 3 -- loss : 1033.4456
# Batch 74 out of 232 in Epoch 3 -- loss : 1088.7903
# Batch 75 out of 232 in Epoch 3 -- loss : 1046.3961
# Batch 76 out of 232 in Epoch 3 -- loss : 1066.7300
# Batch 77 out of 232 in Epoch 3 -- loss : 1074.3490
# Batch 78 out of 232 in Epoch 3 -- loss : 1033.8303
# Batch 79 out of 232 in Epoch 3 -- loss : 1015.9016
# Batch 80 out of 232 in Epoch 3 -- loss : 1058.2451
# Batch 81 out of 232 in Epoch 3 -- loss : 1084.9155
# Batch 82 out of 232 in Epoch 3 -- loss : 1039.3755
# Batch 83 out of 232 in Epoch 3 -- loss : 1072.2670
# Batch 84 out of 232 in Epoch 3 -- loss : 1040.0615
# Batch 85 out of 232 in Epoch 3 -- loss : 1035.7144
# Batch 86 out of 232 in Epoch 3 -- loss : 1024.7261
# Batch 87 out of 232 in Epoch 3 -- loss : 1026.7622
# Batch 88 out of 232 in Epoch 3 -- loss : 1089.0918
# Batch 89 out of 232 in Epoch 3 -- loss : 1025.9669
# Batch 90 out of 232 in Epoch 3 -- loss : 1121.8552
# Batch 91 out of 232 in Epoch 3 -- loss : 1055.6311
# Batch 92 out of 232 in Epoch 3 -- loss : 1023.9957
# Batch 93 out of 232 in Epoch 3 -- loss : 1048.5635
# Batch 94 out of 232 in Epoch 3 -- loss : 1064.4125
# Batch 95 out of 232 in Epoch 3 -- loss : 1089.4961
# Batch 96 out of 232 in Epoch 3 -- loss : 1025.2684
# Batch 97 out of 232 in Epoch 3 -- loss : 1047.1755
# Batch 98 out of 232 in Epoch 3 -- loss : 1063.2976
# Batch 99 out of 232 in Epoch 3 -- loss : 1051.1382
# Batch 100 out of 232 in Epoch 3 -- loss : 1051.4128
# Batch 101 out of 232 in Epoch 3 -- loss : 1042.0848
# Batch 102 out of 232 in Epoch 3 -- loss : 1098.7642
# Batch 103 out of 232 in Epoch 3 -- loss : 1073.8428
# Batch 104 out of 232 in Epoch 3 -- loss : 1066.0062
# Batch 105 out of 232 in Epoch 3 -- loss : 1040.0137
# Batch 106 out of 232 in Epoch 3 -- loss : 1048.9004
# Batch 107 out of 232 in Epoch 3 -- loss : 1026.1871
# Batch 108 out of 232 in Epoch 3 -- loss : 1074.4039
# Batch 109 out of 232 in Epoch 3 -- loss : 1116.2125
# Batch 110 out of 232 in Epoch 3 -- loss : 1086.1371
# Batch 111 out of 232 in Epoch 3 -- loss : 1037.6566
# Batch 112 out of 232 in Epoch 3 -- loss : 1070.4167
# Batch 113 out of 232 in Epoch 3 -- loss : 1052.0906
# Batch 114 out of 232 in Epoch 3 -- loss : 1034.0442
# Batch 115 out of 232 in Epoch 3 -- loss : 1055.3883
# Batch 116 out of 232 in Epoch 3 -- loss : 1053.1504
# Batch 117 out of 232 in Epoch 3 -- loss : 1032.8590
# Batch 118 out of 232 in Epoch 3 -- loss : 1097.7242
# Batch 119 out of 232 in Epoch 3 -- loss : 1088.3132
# Batch 120 out of 232 in Epoch 3 -- loss : 1039.2028
# Batch 121 out of 232 in Epoch 3 -- loss : 1047.9727
# Batch 122 out of 232 in Epoch 3 -- loss : 1042.3567
# Batch 123 out of 232 in Epoch 3 -- loss : 1033.6243
# Batch 124 out of 232 in Epoch 3 -- loss : 1037.1383
# Batch 125 out of 232 in Epoch 3 -- loss : 1067.8125
# Batch 126 out of 232 in Epoch 3 -- loss : 1077.4563
# Batch 127 out of 232 in Epoch 3 -- loss : 1053.0211
# Batch 128 out of 232 in Epoch 3 -- loss : 1028.6683
# Batch 129 out of 232 in Epoch 3 -- loss : 1039.2094
# Batch 130 out of 232 in Epoch 3 -- loss : 1019.7047
# Batch 131 out of 232 in Epoch 3 -- loss : 1060.6394
# Batch 132 out of 232 in Epoch 3 -- loss : 1092.5925
# Batch 133 out of 232 in Epoch 3 -- loss : 1131.2676
# Batch 134 out of 232 in Epoch 3 -- loss : 1040.8754
# Batch 135 out of 232 in Epoch 3 -- loss : 1043.1875
# Batch 136 out of 232 in Epoch 3 -- loss : 1048.3992
# Batch 137 out of 232 in Epoch 3 -- loss : 1048.8789
# Batch 138 out of 232 in Epoch 3 -- loss : 1025.5332
# Batch 139 out of 232 in Epoch 3 -- loss : 1020.5332
# Batch 140 out of 232 in Epoch 3 -- loss : 1020.4941
# Batch 141 out of 232 in Epoch 3 -- loss : 1076.7532
# Batch 142 out of 232 in Epoch 3 -- loss : 1060.5778
# Batch 143 out of 232 in Epoch 3 -- loss : 1042.5364
# Batch 144 out of 232 in Epoch 3 -- loss : 1039.0856
# Batch 145 out of 232 in Epoch 3 -- loss : 1069.1321
# Batch 146 out of 232 in Epoch 3 -- loss : 1046.0754
# Batch 147 out of 232 in Epoch 3 -- loss : 1104.0094
# Batch 148 out of 232 in Epoch 3 -- loss : 1161.0879
# Batch 149 out of 232 in Epoch 3 -- loss : 1038.1696
# Batch 150 out of 232 in Epoch 3 -- loss : 1061.4421
# Batch 151 out of 232 in Epoch 3 -- loss : 1029.7906
# Batch 152 out of 232 in Epoch 3 -- loss : 1068.5891
# Batch 153 out of 232 in Epoch 3 -- loss : 1053.5199
# Batch 154 out of 232 in Epoch 3 -- loss : 1055.6042
# Batch 155 out of 232 in Epoch 3 -- loss : 1042.8567
# Batch 156 out of 232 in Epoch 3 -- loss : 1062.4606
# Batch 157 out of 232 in Epoch 3 -- loss : 1039.1504
# Batch 158 out of 232 in Epoch 3 -- loss : 1040.8304
# Batch 159 out of 232 in Epoch 3 -- loss : 1050.7461
# Batch 160 out of 232 in Epoch 3 -- loss : 1054.6589
# Batch 161 out of 232 in Epoch 3 -- loss : 1080.8024
# Batch 162 out of 232 in Epoch 3 -- loss : 1102.1293
# Batch 163 out of 232 in Epoch 3 -- loss : 1096.8093
# Batch 164 out of 232 in Epoch 3 -- loss : 1062.6680
# Batch 165 out of 232 in Epoch 3 -- loss : 1050.1230
# Batch 166 out of 232 in Epoch 3 -- loss : 1054.9164
# Batch 167 out of 232 in Epoch 3 -- loss : 1086.0035
# Batch 168 out of 232 in Epoch 3 -- loss : 1048.9094
# Batch 169 out of 232 in Epoch 3 -- loss : 1050.7992
# Batch 170 out of 232 in Epoch 3 -- loss : 1091.3152
# Batch 171 out of 232 in Epoch 3 -- loss : 1026.0149
# Batch 172 out of 232 in Epoch 3 -- loss : 1101.9246
# Batch 173 out of 232 in Epoch 3 -- loss : 1093.9125
# Batch 174 out of 232 in Epoch 3 -- loss : 1052.9398
# Batch 175 out of 232 in Epoch 3 -- loss : 1035.5750
# Batch 176 out of 232 in Epoch 3 -- loss : 1046.4504
# Batch 177 out of 232 in Epoch 3 -- loss : 1057.1031
# Batch 178 out of 232 in Epoch 3 -- loss : 1075.7992
# Batch 179 out of 232 in Epoch 3 -- loss : 1017.4090
# Batch 180 out of 232 in Epoch 3 -- loss : 1022.8535
# Batch 181 out of 232 in Epoch 3 -- loss : 1073.7633
# Batch 182 out of 232 in Epoch 3 -- loss : 1036.2942
# Batch 183 out of 232 in Epoch 3 -- loss : 1113.9832
# Batch 184 out of 232 in Epoch 3 -- loss : 1079.3844
# Batch 185 out of 232 in Epoch 3 -- loss : 1046.5000
# Batch 186 out of 232 in Epoch 3 -- loss : 1059.5035
# Batch 187 out of 232 in Epoch 3 -- loss : 1023.8898
# Batch 188 out of 232 in Epoch 3 -- loss : 1046.3707
# Batch 189 out of 232 in Epoch 3 -- loss : 1060.3796
# Batch 190 out of 232 in Epoch 3 -- loss : 1037.3132
# Batch 191 out of 232 in Epoch 3 -- loss : 1082.7649
# Batch 192 out of 232 in Epoch 3 -- loss : 1075.1539
# Batch 193 out of 232 in Epoch 3 -- loss : 1023.7168
# Batch 194 out of 232 in Epoch 3 -- loss : 1083.9867
# Batch 195 out of 232 in Epoch 3 -- loss : 1034.8961
# Batch 196 out of 232 in Epoch 3 -- loss : 1059.6086
# Batch 197 out of 232 in Epoch 3 -- loss : 1120.4714
# Batch 198 out of 232 in Epoch 3 -- loss : 1040.7988
# Batch 199 out of 232 in Epoch 3 -- loss : 1044.1379
# Batch 200 out of 232 in Epoch 3 -- loss : 1050.9688
# Batch 201 out of 232 in Epoch 3 -- loss : 1048.3492
# Batch 202 out of 232 in Epoch 3 -- loss : 1032.9890
# Batch 203 out of 232 in Epoch 3 -- loss : 1066.5637
# Batch 204 out of 232 in Epoch 3 -- loss : 1040.9004
# Batch 205 out of 232 in Epoch 3 -- loss : 1100.9407
# Batch 206 out of 232 in Epoch 3 -- loss : 1076.8571
# Batch 207 out of 232 in Epoch 3 -- loss : 1045.5332
# Batch 208 out of 232 in Epoch 3 -- loss : 1036.2605
# Batch 209 out of 232 in Epoch 3 -- loss : 1057.7473
# Batch 210 out of 232 in Epoch 3 -- loss : 1128.3997
# Batch 211 out of 232 in Epoch 3 -- loss : 1061.6735
# Batch 212 out of 232 in Epoch 3 -- loss : 1062.5188
# Batch 213 out of 232 in Epoch 3 -- loss : 1077.8386
# Batch 214 out of 232 in Epoch 3 -- loss : 1067.3414
# Batch 215 out of 232 in Epoch 3 -- loss : 1044.2136
# Batch 216 out of 232 in Epoch 3 -- loss : 1048.9570
# Batch 217 out of 232 in Epoch 3 -- loss : 1037.7594
# Batch 218 out of 232 in Epoch 3 -- loss : 1075.6031
# Batch 219 out of 232 in Epoch 3 -- loss : 1115.5684
# Batch 220 out of 232 in Epoch 3 -- loss : 1061.5219
# Batch 221 out of 232 in Epoch 3 -- loss : 1101.9004
# Batch 222 out of 232 in Epoch 3 -- loss : 1058.6973
# Batch 223 out of 232 in Epoch 3 -- loss : 1047.2719
# Batch 224 out of 232 in Epoch 3 -- loss : 1053.7141
# Batch 225 out of 232 in Epoch 3 -- loss : 1110.9446
# Batch 226 out of 232 in Epoch 3 -- loss : 1047.4714
# Batch 227 out of 232 in Epoch 3 -- loss : 1039.7438
# Batch 228 out of 232 in Epoch 3 -- loss : 1060.7903
# Batch 229 out of 232 in Epoch 3 -- loss : 1101.5758
# Batch 230 out of 232 in Epoch 3 -- loss : 1031.3875
# Batch 231 out of 232 in Epoch 3 -- loss : 1082.5261
# Batch 232 out of 232 in Epoch 3 -- loss : 1046.9246
# Epoch 3 -- loss : 1059.4586
# Batch 1 out of 232 in Epoch 4 -- loss : 1036.2988
# Batch 2 out of 232 in Epoch 4 -- loss : 1055.1350
# Batch 3 out of 232 in Epoch 4 -- loss : 1113.7549
# Batch 4 out of 232 in Epoch 4 -- loss : 1061.8883
# Batch 5 out of 232 in Epoch 4 -- loss : 1115.1124
# Batch 6 out of 232 in Epoch 4 -- loss : 1051.8844
# Batch 197 out of 232 in Epoch 4 -- loss : 1039.7493
# Batch 198 out of 232 in Epoch 4 -- loss : 1042.1996
# Batch 199 out of 232 in Epoch 4 -- loss : 1046.4167
# Batch 200 out of 232 in Epoch 4 -- loss : 1109.0680
# Batch 201 out of 232 in Epoch 4 -- loss : 1049.9758
# Batch 202 out of 232 in Epoch 4 -- loss : 1034.3035
# Batch 203 out of 232 in Epoch 4 -- loss : 1068.0247
# Batch 204 out of 232 in Epoch 4 -- loss : 1041.2676
# Batch 205 out of 232 in Epoch 4 -- loss : 1054.4890
# Batch 206 out of 232 in Epoch 4 -- loss : 1093.8503
# Batch 207 out of 232 in Epoch 4 -- loss : 1045.8254
# Batch 208 out of 232 in Epoch 4 -- loss : 1036.3860
# Batch 209 out of 232 in Epoch 4 -- loss : 1058.4164
# Batch 210 out of 232 in Epoch 4 -- loss : 1079.6910
# Batch 211 out of 232 in Epoch 4 -- loss : 1063.7617
# Batch 212 out of 232 in Epoch 4 -- loss : 1110.6445
# Batch 213 out of 232 in Epoch 4 -- loss : 1039.5570
# Batch 214 out of 232 in Epoch 4 -- loss : 1068.8887
# Batch 215 out of 232 in Epoch 4 -- loss : 1093.4407
# Batch 216 out of 232 in Epoch 4 -- loss : 1050.6969
# Batch 217 out of 232 in Epoch 4 -- loss : 1039.2239
# Batch 218 out of 232 in Epoch 4 -- loss : 1077.0433
# Batch 219 out of 232 in Epoch 4 -- loss : 1132.1781
# Batch 220 out of 232 in Epoch 4 -- loss : 1061.0593
# Batch 221 out of 232 in Epoch 4 -- loss : 1048.3210
# Batch 222 out of 232 in Epoch 4 -- loss : 1058.9391
# Batch 223 out of 232 in Epoch 4 -- loss : 1048.3894
# Batch 224 out of 232 in Epoch 4 -- loss : 1104.2468
# Batch 225 out of 232 in Epoch 4 -- loss : 1061.0153
# Batch 226 out of 232 in Epoch 4 -- loss : 1048.2390
# Batch 227 out of 232 in Epoch 4 -- loss : 1040.9812
# Batch 228 out of 232 in Epoch 4 -- loss : 1061.5004
# Batch 229 out of 232 in Epoch 4 -- loss : 1100.4711
# Batch 230 out of 232 in Epoch 4 -- loss : 1032.6992
# Batch 231 out of 232 in Epoch 4 -- loss : 1083.7711
# Batch 232 out of 232 in Epoch 4 -- loss : 1048.1801
# Epoch 4 -- loss : 1059.7061

# %% [markdown]
# # Test

# %%
# Test the accuracy of the model
correct_label_count = 0

# We only need to batchify the test set for memory requirements
for batch in np.array_split(test_indices,  len(test_indices) // batch_size):
    test_spike_train = torch.FloatTensor(spike_train[batch].todense()).to(device)

    # Same forward propagation as before
    layer_1_spikes = run_spiking_layer(test_spike_train, w1)
    layer_2_spikes = run_spiking_layer(layer_1_spikes, w2)
    network_output = torch.sum(layer_2_spikes, 2)  # Count the spikes over time axis

    # Do the prediction by selecting the output neuron with the most number of spikes
    _, am = torch.max(network_output, 1)
    correct_label_count += np.sum(am.detach().cpu().numpy() == y[batch])

print("Model accuracy on test set: %.3f" % (correct_label_count / len(test_indices)))
# Out:
# Model accuracy on test set: 0.096
